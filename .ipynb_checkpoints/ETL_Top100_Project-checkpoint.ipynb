# %%
#Using Spotipy, a lightweight Python library for the Spotify Web API. Guide at link below
#https://spotipy.readthedocs.io/en/latest/#
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import spotipy, sys, csv
import pprint as pp
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from spotipy.oauth2 import SpotifyClientCredentials

#Load Application ID and API Key for Spotify API
client_credentials_manager = SpotifyClientCredentials(client_id='0de0796ce8d6430d9896525ccb8c845d',
                                                      client_secret='4b1c63bc8de34e7a9cc75b105f3c3875')
spotify = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
#Read in csv of Singles and convert to DataFrame
top100singles = pd.read_csv('top100singles.csv')
list_of_dicts = []

#Loop Through all Singles in top100 singles csv
for index,row in top100singles.iterrows():
    
    title_and_artist = row['Single'] + ' ' + row['Artist']

    #Make API Call using search method, querying for "Title, Artist"
    #Limit to just the top response
    results = spotify.search(q=title_and_artist, type='track',limit=1)

    #temporary dictionary to store all of the track details
    temp = {}
    temp['name'] = results['tracks']['items'][0]['name']
    temp['popularity'] = results['tracks']['items'][0]['popularity']

    #if there are multiple artist on album, store as one value separated by commas
    multi_Artist = False
    for j in range(len(results['tracks']['items'][0]['artists'])):
        if multi_Artist == False:
            temp['artists'] = results['tracks']['items'][0]['artists'][j]['name']
            multi_Artist = True
        else:
            temp['artists'] = temp['artists'] + ', ' + results['tracks']['items'][0]['artists'][j]['name']

    list_of_dicts.append(temp)

# %%
#convert list of dictionaries to DataFrame
df = pd.DataFrame(list_of_dicts)
df.columns = ['Artist(s)', 'Title (Spotify)','Popularity']
df.head()
# Out:
#                                            Artist(s)  \
# 0  Bing Crosby, Ken Darby Singers, John Scott Tro...
# 1                                         Elton John
# 2                                        Mungo Jerry
# 3                                        Bing Crosby
# 4                            Bill Haley & His Comets
#
#                                      Title (Spotify)  Popularity
# 0                                    White Christmas          72
# 1  Something About The Way You Look Tonight - Edi...          60
# 2                                  In the Summertime          67
# 3                                       Silent Night          47
# 4                (We're Gonna) Rock Around The Clock          61

# %%
#concatenate results, and start index at 1
wiki_and_spotify = pd.concat([top100singles,df],axis=1)
wiki_and_spotify.index += 1
wiki_and_spotify = wiki_and_spotify[['Artist','Single','Release Year','Sales (in millions)','Popularity']]
wiki_and_spotify.head()
# Out:
#                     Artist                                             Single  \
# 1              Bing Crosby                                    White Christmas
# 2               Elton John  Candle in the Wind 1997 / Something About the ...
# 3              Mungo Jerry                                  In the Summertime
# 4              Bing Crosby                                       Silent Night
# 5  Bill Haley & His Comets                              Rock Around the Clock
#
#    Release Year  Sales (in millions)  Popularity
# 1          1942                 50.0          72
# 2          1997                 33.0          60
# 3          1970                 30.0          67
# 4          1935                 30.0          47
# 5          1954                 25.0          61

# %%
#output sinlges joined results to csv
wiki_and_spotify.to_csv('top100_singles_output.csv',index=False)

# %%
#plot Popularity against release year
wiki_and_spotify.reset_index().plot(x='Release Year',y='Popularity',kind='scatter')
plt.show()

# %%
#Read in csv of Artists and convert to DataFrame
top100artists = pd.read_csv('top100artists.csv')
list_of_dicts = []
count = 0

#Loop Through all Artist in top100 artist csv
for index,row in top100artists.iterrows():
    artist = row['Artist']
    results = spotify.search(q=artist, type='artist',limit=1)
    
    #store name and popularity in dictionary
    temp = {}
    temp['name'] = results['artists']['items'][0]['name']
    temp['popularity'] = results['artists']['items'][0]['popularity']

    list_of_dicts.append(temp)

# %%
#convert list of dictionaries to DataFrame
top100_artists_df = pd.DataFrame(list_of_dicts)
top100_artists_df

# %%
#join with original csv and reformat
top100_artists_joined = pd.concat([top100_artists_df,top100artists],axis=1)
top100_artists_joined.index+=1
top100_artists_joined = top100_artists_joined[['Artist','Sales','popularity','Country','Formation','End','Genre']]
top100_artists_joined.head()
# Out:
#             Artist  Sales  popularity         Country  Formation   End  \
# 1      The Beatles    600          90  United Kingdom       1960  1970
# 2    Elvis Presley    600          81   United States       1954  1977
# 3  Michael Jackson    350          85   United States       1964  2009
# 4       Elton John    300          85  United Kingdom       1964  2019
# 5          Madonna    300          80   United States       1979  2019
#
#             Genre
# 1           Rock
# 2  Rock and roll
# 3            Pop
# 4            Pop
# 5            Pop

# %%
for i in range(1,top100_artists_joined['Genre'].count()+1):
    genre = top100_artists_joined['Genre'][i].lower()
    if 'alter' in genre:
        top100_artists_joined['Genre'][i] = 'Alt Rock'
    elif 'country' in genre:
        top100_artists_joined['Genre'][i] = 'Country'
    elif 'folk' in genre:
        top100_artists_joined['Genre'][i] = 'Folk'
    elif 'funk' in genre:
        top100_artists_joined['Genre'][i] = 'Funk'
    elif ('hard' in genre or 'metal' in genre):
        top100_artists_joined['Genre'][i] = 'Hard Rock'
    elif 'hip' in genre:
        top100_artists_joined['Genre'][i] = 'Hip-Hop'
    elif 'latin' in genre:
        top100_artists_joined['Genre'][i] = 'Latin'
    elif 'pop' in genre:
        top100_artists_joined['Genre'][i] = 'Pop'
    elif 'r&b' in genre:
        top100_artists_joined['Genre'][i] = 'R&B'
    elif 'rock' in genre:
        top100_artists_joined['Genre'][i] = 'Rock'

# %%
top100_artists_joined
# Out:
#                     Artist  Sales  popularity         Country  Formation  \
# 1              The Beatles    600          90  United Kingdom       1960
# 2            Elvis Presley    600          81   United States       1954
# 3          Michael Jackson    350          85   United States       1964
# 4               Elton John    300          85  United Kingdom       1964
# 5                  Madonna    300          80   United States       1979
# 6             Led Zeppelin    300          82  United Kingdom       1968
# 7                  Rihanna    250          90        Barbados       2005
# 8               Pink Floyd    250          83  United Kingdom       1965
# 9                   Eminem    220          93   United States       1996
# 10            Taylor Swift    200          94   United States       2006
# 11            Mariah Carey    200          82   United States       1988
# 12                  Eagles    200          79   United States       1971
# 13                   Queen    200          91  United Kingdom       1971
# 14         Whitney Houston    200          83   United States       1977
# 15             Celine Dion    200          79          Canada       1981
# 16                   AC/DC    200          85       Australia       1973
# 17      The Rolling Stones    200          83  United Kingdom       1962
# 18            Garth Brooks    160          54   United States       1989
# 19                   Drake    150          97          Canada       2001
# 20              Ed Sheeran    150          97  United Kingdom       2004
# 21           Justin Bieber    150          93          Canada       2008
# 22              Billy Joel    150          79   United States       1964
# 23                      U2    150          82         Ireland       1976
# 24        Barbra Streisand    150          69   United States       1960
# 25            Phil Collins    150          79  United Kingdom       1980
# 26               Aerosmith    150          79   United States       1970
# 27                    ABBA    150          80          Sweden       1972
# 28           Frank Sinatra    150          82   United States       1935
# 29              Katy Perry    143          88   United States       2001
# 30              Kanye West    140          96   United States       1996
# ..                     ...    ...         ...             ...        ...
# 71             Tina Turner    100          72   United States       1955
# 72          Linda Ronstadt    100          64   United States       1967
# 73            Donna Summer    100          68   United States       1968
# 74          The Beach Boys    100          76   United States       1961
# 75                 The Who    100          75  United Kingdom       1964
# 76             Barry White    100          68   United States       1972
# 77            Shania Twain     90          74          Canada       1993
# 78                    Pink     90          83   United States       1995
# 79          The Carpenters     90          71   United States       1969
# 80           Lionel Richie     90          74   United States       1968
# 81      Earth, Wind & Fire     90          76   United States       1969
# 82             Johnny Cash     90          79   United States       1954
# 83       Justin Timberlake     88          82   United States       1992
# 84             Nicki Minaj     85          91   United States       2008
# 85                  R.E.M.     85          76   United States       1980
# 86                Flo Rida     80          81   United States       2007
# 87               Van Halen     80          75   United States       1978
# 88          Ayumi Hamasaki     80          61           Japan       1998
# 89   Red Hot Chili Peppers     80          86   United States       1983
# 90          George Michael     80          76  United Kingdom       1981
# 91               Foreigner     80          72   United States       1976
# 92               The Doors     80          77   United States       1965
# 93               Meat Loaf     80          66   United States       1968
# 94               Tom Petty     80          73   United States       1976
# 95         Johnny Hallyday     80          65          France       1957
# 96              Tim McGraw     75          76   United States       1990
# 97                 Journey     75          77   United States       1973
# 98                   Usher     75          83   United States       1991
# 99     The Black Eyed Peas     75          85   United States       1995
# 100     Christina Aguilera     75          81   United States       1993
#
#       End      Genre
# 1    1970       Rock
# 2    1977       Rock
# 3    2009        Pop
# 4    2019        Pop
# 5    2019        Pop
# 6    1980  Hard Rock
# 7    2019        R&B
# 8    1996       Rock
# 9    2019    Hip-Hop
# 10   2019        Pop
# 11   2019        R&B
# 12   1980       Rock
# 13   2019       Rock
# 14   2012        R&B
# 15   2019        Pop
# 16   2019  Hard Rock
# 17   2019       Rock
# 18   2019    Country
# 19   2019    Hip-Hop
# 20   2019        Pop
# 21   2019        Pop
# 22   2019        Pop
# 23   2019       Rock
# 24   2019        Pop
# 25   2011       Rock
# 26   2019  Hard Rock
# 27   1982        Pop
# 28   1995        Pop
# 29   2019        Pop
# 30   2019    Hip-Hop
# ..    ...        ...
# 71   2019       Rock
# 72   2019       Rock
# 73   2012        Pop
# 74   2019       Rock
# 75   2019       Rock
# 76   2003        R&B
# 77   2019    Country
# 78   2019        Pop
# 79   1983        Pop
# 80   2019        Pop
# 81   2019       Funk
# 82   2003    Country
# 83   2019        Pop
# 84   2019    Hip-Hop
# 85   2011   Alt Rock
# 86   2019    Hip-Hop
# 87   2019  Hard Rock
# 88   2019        Pop
# 89   2019       Funk
# 90   2016        Pop
# 91   2019       Rock
# 92   1973       Rock
# 93   2019       Rock
# 94   2017       Rock
# 95   2017       Rock
# 96   2019    Country
# 97   2019       Rock
# 98   2019        R&B
# 99   2019    Hip-Hop
# 100  2019        R&B
#
# [100 rows x 7 columns]

# %%
#Export to csv
top100_artists_joined.to_csv('top100_artist_output.csv',index=False)
